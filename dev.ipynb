# %%
import pandas as pd

# %%
df = pd.read_parquet("latents.parquet")
df
# Out:
#        latent_0  latent_1  latent_2  latent_3  latent_4  latent_5  latent_6  \
# 0      0.151596  0.130750 -0.020572 -0.008702  0.119883 -0.098603 -0.162638
# 1      0.129649  0.258579 -0.082505 -0.050313  0.170999  0.063026  0.304227
# 2      0.138823  0.103872  0.029118 -0.096614 -0.088815 -0.079977 -0.169806
# 3      0.772842 -0.027351  0.159511  0.023100  0.065235  0.285410 -0.047652
# 4      0.198937  0.014087  0.087423 -0.047640  0.080979  0.145495  0.349868
# ...         ...       ...       ...       ...       ...       ...       ...
# 19995 -0.137997  0.219955  0.002777 -0.065454  0.087888 -0.023477  0.017132
# 19996  0.011359 -0.009429  0.041069 -0.062789  0.040337  0.038660  0.028385
# 19997  0.621864 -0.151340  0.030576 -0.021610  0.098567  0.064239  0.159389
# 19998 -0.294792 -0.242589 -0.051790 -0.131470  0.065988  0.148553  0.152671
# 19999  0.024850  0.075206  0.042131 -0.011633  0.033424 -0.091490  0.096084
#
#        latent_7  latent_8  latent_9  ...  latent_55  latent_56  latent_57  \
# 0      0.007038 -0.078353  0.133152  ...   0.130211   0.018141  -0.005269
# 1      0.125443  0.022939  0.195487  ...   0.138282   0.386602   0.360405
# 2      0.093757  0.014981  0.090413  ...   0.143397   0.116483   0.083717
# 3     -0.123610  0.099488  0.094026  ...   0.240797   0.097864   0.528038
# 4     -0.066920  0.019068  0.200652  ...   0.268339   0.515855   0.252270
# ...         ...       ...       ...  ...        ...        ...        ...
# 19995  0.064848  0.269569  0.089481  ...  -0.044000   0.154012   0.223932
# 19996 -0.026319 -0.035022  0.010038  ...   0.133058   0.088053   0.135737
# 19997 -0.090356  0.200330 -0.193479  ...   0.131447   0.072271   0.176040
# 19998 -0.056108  0.036137  0.007123  ...   0.339314   0.208420   0.320191
# 19999  0.016717 -0.009942  0.073272  ...  -0.020035   0.008253  -0.100172
#
#        latent_58  latent_59  latent_60  latent_61  latent_62  latent_63  label
# 0      -0.121589  -0.460095   0.307106  -0.301447  -0.003318  -0.378512      7
# 1      -0.179235   0.011761   0.023306  -0.226187  -0.109470  -0.207471      2
# 2      -0.093438  -0.491476  -0.047727  -0.051189  -0.078834  -0.222641      1
# 3      -0.110848  -0.870573  -0.089326   0.395604  -0.146013   0.027837      0
# 4      -0.191705  -0.499892   0.360893  -0.183528   0.028938  -0.517696      4
# ...          ...        ...        ...        ...        ...        ...    ...
# 19995   0.017325   0.008113   0.025702   0.031547   0.003976  -0.014437     -1
# 19996  -0.078856  -0.367552  -0.049795   0.019604  -0.051508  -0.018510     -1
# 19997   0.010664  -0.558209  -0.108308   0.253535  -0.019147  -0.164806     -1
# 19998  -0.105965  -0.100134  -0.127936   0.090252   0.024071  -0.050594     -1
# 19999  -0.008543  -0.224292   0.027945  -0.063565  -0.069754  -0.058425     -1
#
# [20000 rows x 65 columns]

# %%
reps = dict()
for label, group in df.groupby("label"):
    group = group.mean(axis=0)
    reps[label] = group

# %%
corr = pd.DataFrame(columns=reps.keys(), index=reps.keys())
for row in reps.keys():
    for col in reps.keys():
        if row == col:
            rep = reps[row]
            points = df[df["label"] == row]
            d = points - rep
            d = d.abs().mean(axis=1)
            corr.at[row, col] = d.mean()
            continue
        dist = reps[row] - reps[col]
        dist = dist.abs().mean()
        corr.at[row, col] = dist
corr
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 9
#       7     d = points - rep
#       8     d = d.abs().mean(axis=1)
# ----> 9     dist.at[row, col] = d.mean()
#      10     continue
#      11 dist = reps[row] - reps[col]
#
# AttributeError: 'numpy.float64' object has no attribute 'at'
